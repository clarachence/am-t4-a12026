# %% [markdown]
# <a href="https://colab.research.google.com/github/clarachence/am-t4-a12026/blob/main/NeuralizadorCredit0423.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pipeline | Carregamento e Detecção de Anomalias [Fase 1  - credit_data]

# %% [markdown]
# ## Importar Dados

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Biblioteca de dados

# %%
# !pip -q install plotly
# !pip -q install yellowbrick

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import seaborn.palettes
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# ## Carregar Digest de base_credit

# %%
import pickle

# %%
with open('/content/drive/MyDrive/am-t4/credit.pkt', 'rb') as f:
  X_credit_treinamento, Y_credit_treinamento, X_credit_teste, Y_credit_teste = pickle.load(f)

# %%
X_credit_treinamento.shape, Y_credit_treinamento.shape
# Out:
# ((1700, 3), (300, 3))

# %%
X_credit_teste.shape, Y_credit_teste.shape
# Out:
# ((1700, 3), (300, 3))

# %%
from sklearn.naive_bayes import GaussianNB

# %%
naive_credit_data = GaussianNB()
naive_credit_data.fit(X_credit_treinamento, Y_credit_treinamento)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_563/2553779636.py in <cell line: 0>()
#       1 naive_credit_data = GaussianNB()
# ----> 2 naive_credit_data.fit(X_credit_treinamento, Y_credit_treinamento)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     263             Returns the instance itself.
#     264         """
# --> 265         y = validate_data(self, y=y)
#     266         return self._partial_fit(
#     267             X, y, np.unique(y), _refit=True, sample_weight=sample_weight
#
# ...
